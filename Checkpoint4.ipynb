# %%
import pandas as pd ### importing libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df= pd.read_csv("kc_house_data.csv")  ###importing data
df.head()   ###viewing data
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()        ### showing overall data info
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()     ###displaying missing values there's none so data is ready to be treated
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(12,10))       ### coorelation heat map for future selection
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
df.columns   ### display all comlumns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cor_target = abs(cor['price'])     ### showing well coorelated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# price            1.000000
# bathrooms        0.525138
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# Name: price, dtype: float64

# %%
Hdf = df.drop(['id', 'date', 'bedrooms', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_lot15'],axis = 1)      ### leaving only the well coorelated features
Hdf.head()
# Out:
#       price  bathrooms  sqft_living  grade  sqft_above  sqft_living15
# 0  221900.0       1.00         1180      7        1180           1340
# 1  538000.0       2.25         2570      7        2170           1690
# 2  180000.0       1.00          770      6         770           2720
# 3  604000.0       3.00         1960      7        1050           1360
# 4  510000.0       2.00         1680      8        1680           1800

# %%
sns.pairplot(Hdf)    ### pairplot of our data
plt.show()

# %%
plt.figure(figsize = (15,5))   ### number of bathrooms \ price
sns.pointplot(data = Hdf, x = 'bathrooms', y = 'price')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
from sklearn.model_selection import train_test_split    ### splitting data to train and test to train our model and test its accuracy
x=Hdf["sqft_living"].values[:,np.newaxis] 
y=Hdf["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
from sklearn.linear_model import LinearRegression  ### using linear regression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
model=LinearRegression()   
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="r")     ### plotting linear regression
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()                     ### after displaying the plot we can see some outliers

# %%
Difference_N1 = y_test - model.predict(x_test)      ### we plot the difference between the predicted model and the results as we can see the model is working good so far
plt.plot((Difference_N1), marker='.', linestyle='-' )

# %%
R2_1 = metrics.r2_score(y_test,model.predict(x_test))     ### we calculated main square error to see how the model is doing and we notice that half of the results are based on the model's input
print("R squared value 1 =", R2_1)
# Out:
# R squared value 1 = 0.4891139430408491

# %%
x=Hdf[["bathrooms","sqft_living","grade","sqft_above","sqft_living15"]]  ###applaying multi linear regression
y=Hdf["price"].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
model=LinearRegression() 
model.fit(x_train,y_train) 
predicted=model.predict(x_test)

# %%
Difference_N2 = y_test - model.predict(x_test)
plt.plot((Difference_N2), marker='.', linestyle='-' )

# %%
R2_2 = metrics.r2_score(y_test,model.predict(x_test)) 
print("R squared 2 =", R2_2)
# Out:
# R squared 2 = 0.5367957938608929

# %%
plt.plot((Difference_N2 - Difference_N1), marker='.', linestyle='-' )   ### comparing the multi linear with the linear regression

# %%
print("The difference between the mean squared error :", R2_2-R2_1)  ### we notice that multi linear is a little bit better than linear regression
# Out:
# The difference between the mean squared error : 0.047681850820043836

# %%
from sklearn.preprocessing import PolynomialFeatures ### importing libriries for polynomial regression

# %%
x=Hdf[["bathrooms","sqft_living","grade","sqft_above","sqft_living15"]]  ### applaying polynomial regression
y=Hdf["price"].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=50)  
lg=LinearRegression()
poly=PolynomialFeatures(degree=2)

# %%
x_train_fit = poly.fit_transform(x_train) 
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

# %%
Difference_N3 = y_test - model.predict(x_test)
plt.plot((Difference_N3), marker='.', linestyle='-' )

# %%
R2_3 = metrics.r2_score(y_test,model.predict(x_test))
print("R squared 3 =", R2_3)
# Out:
# R squared 3 = 0.5367957938608929

# %%
print("The difference between the R squared values :", R2_3 - R2_2)  ### we notice that polynomial regression is better than linear regression and almost as good as multi linear regression
print("The difference between the R squared values :", R2_3 - R2_1)
# Out:
# The difference between the R squared values : 0.0
# The difference between the R squared values : 0.047681850820043836
